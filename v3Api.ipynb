# %%
from apiclient.discovery import build

# %%
api_Key_project31021='AIzaSyANu4XqjBV0EPHw784BwBcGf236ycNT7Y0'

# %%
my_youtube = build("youtube","v3",developerKey=api_Key_project31021)

# %%
type(my_youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
my_youtube

# %% [markdown]
# ## キーワード検索pythonの場合

# %% [markdown]
# Search:list について パラメータなど
# https://developers.google.com/youtube/v3/docs/search/list?hl=j

# %%
request_python = my_youtube.search().list(
    q='python 自動化',
    part='snippet',
    type='video',
    videoCategoryId="27",
    publishedAfter='2016-01-01T00:00:00Z',
    publishedBefore='2019-01-01T00:00:00Z'
)

# %%
response_python=request_python()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2a4f47390798> in <module>()
# ----> 1 response_python=request_python()
#
# TypeError: 'HttpRequest' object is not callable

# %%
response_python=request_python.execute()

# %% [markdown]
# #### kind／ APIの種類
# #### etag／ タグ情報
# #### nextPageToken／ 次のページに関する情報
# #### regionCode／ エリアコード
# #### pageInfo／ APIリクエスト結果の概要
# #### items／ 検索結果の詳細リスト

# %%
response_python

# %%
type(response_python)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a29d3012387b> in <module>()
# ----> 1 type(response_python)
#
# NameError: name 'response_python' is not defined

# %%
response_python.keys()

# %%
response_python['pageInfo']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dbe5d4b78782> in <module>()
# ----> 1 response_python['pageInfo']
#
# NameError: name 'response_python' is not defined

# %%
response_python['pageInfo']['totalResults']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4a209de70b88> in <module>()
# ----> 1 response_python['pageInfo']['totalResults']
#
# NameError: name 'response_python' is not defined

# %% [markdown]
# ### 月ごとに取得

# %%
year = ["2016","2017","2018","2019"]
month = ["01","02","03","04","05","06","07","08","09","10","11","12"]

# %%
def api_func(word):
    request=my_youtube.search().list(
        q=word,
        part='snippet',
        type='video',
        videoCategoryId="27",
        publishedAfter=my_publishedAfter,
        publishedBefore=my_publishedBefore)
    response = request.execute()
    totalResults = response['pageInfo']['totalResults']
    
    print(word+": " + str(totalResults) + "    "+str(y)+"/"+month[i])
    
    with open('youtubeAPI_'+word+'.csv','a') as csvFile:
      writer = csv.writer(csvFile)
      writer.writerow([str(y),str(i),str(totalResults)])
    csvFile.close()

# %%
import csv

# %%
for y in year:
  for i in range(1,12):
    if(i!=12):
      next_month = month[i+1]
      my_publishedAfter=y+"-"+month[i]+"-01T00:00:00Z"
      my_publishedBefore=y+"-"+next_month+"-01T00:00:00Z"
      api_func('python 自動化')
    else:
      my_publishedAfter=y+"-12-01T00:00:00Z"
      my_publishedBefore=str(int(y)+1)+"-01-01T00:00:00Z"
      api_func('python 自動化')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-38-6ca24fd9632d> in <module>()
#       5       my_publishedAfter=y+"-"+month[i]+"-01T00:00:00Z"
#       6       my_publishedBefore=y+"-"+next_month+"-01T00:00:00Z"
# ----> 7       api_func('python 自動化')
#       8     else:
#       9       my_publishedAfter=y+"-12-01T00:00:00Z"
#
# <ipython-input-35-5b8ad956d825> in api_func(word)
#       7         publishedAfter=my_publishedAfter,
#       8         publishedBefore=my_publishedBefore)
# ----> 9     response = request.execute()
#      10     totalResults = response['pageInfo']['totalResults']
#      11
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     896             callback(resp)
#     897         if resp.status >= 300:
# --> 898             raise HttpError(resp, content, uri=self.uri)
#     899         return self.postproc(resp, content)
#     900
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/search?q=python+%E8%87%AA%E5%8B%95%E5%8C%96&part=snippet&type=video&videoCategoryId=27&publishedAfter=2016-02-01T00%3A00%3A00Z&publishedBefore=2016-03-01T00%3A00%3A00Z&key=AIzaSyANu4XqjBV0EPHw784BwBcGf236ycNT7Y0&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.">
